# %%
from sys import modules

IN_COLAB = 'google.colab' in modules
if IN_COLAB:
    # !pip install -q ir_axioms[examples] python-terrier

# %%
# Start/initialize PyTerrier.
from pyterrier import started, init

if not started():
    init(tqdm="auto")

# %%
edition = 29
track = "deep.documents"
dataset_name = "msmarco-document/trec-dl-2020"
depth = 20

# %%
from pyterrier.datasets import get_dataset
from ir_datasets import load

dataset = get_dataset(f"irds:{dataset_name}")
ir_dataset = load(dataset_name)

# %%
from pathlib import Path

cache_dir = Path("cache/")
index_dir = cache_dir / "indices" / dataset_name.replace("/", "-")
result_dir = Path(
    "/mnt/ceph/storage/data-in-progress/data-research/"
    "web-search/web-search-trec/trec-system-runs"
) / f"trec{edition}" / track
result_files = list(result_dir.iterdir())

# %%
from pyterrier.io import read_results
from pyterrier import Transformer

results = [Transformer.from_df(read_results(result_file)) for result_file in result_files]
results_names = [result_file.stem.replace("input.", "") for result_file in result_files]

# %%
from pyterrier.index import IterDictIndexer

if not index_dir.exists():
    indexer = IterDictIndexer(str(index_dir.absolute()))
    indexer.index(
        dataset.get_corpus_iter(),
        fields=["body"]
    )

# %%
from ir_axioms.axiom import (
    ArgUC, QTArg, QTPArg, aSL, PROX1, PROX2, PROX3, PROX4, PROX5, TFC1, TFC3, RS_TF, RS_TF_IDF, RS_BM25, RS_PL2, RS_QL,
    AND, LEN_AND, M_AND, LEN_M_AND, DIV, LEN_DIV, M_TDC, LEN_M_TDC, STMC1, STMC1_f, STMC2, STMC2_f, LNC1, TF_LNC, LB1,
    REG, ANTI_REG, ASPECT_REG, REG_f, ANTI_REG_f, ASPECT_REG_f
)

axioms = [
    ~ArgUC(),  # Very slow due to network access.
    ~QTArg(),  # Very slow due to network access.
    ~QTPArg(),  # Very slow due to network access.
    ~aSL(),
    ~LNC1(),
    ~TF_LNC(),
    ~LB1(),
    ~PROX1(),
    ~PROX2(),
    ~PROX3(),
    ~PROX4(),
    ~PROX5(),
    ~REG(),
    ~REG_f(),
    ~ANTI_REG(),
    ~ANTI_REG_f(),
    ~ASPECT_REG(),
    ~ASPECT_REG_f(),
    ~AND(),
    ~LEN_AND(),
    ~M_AND(),
    ~LEN_M_AND(),
    ~DIV(),
    ~LEN_DIV(),
    ~RS_TF(),
    ~RS_TF_IDF(),
    ~RS_BM25(),
    ~RS_PL2(),
    ~RS_QL(),
    ~TFC1(),
    ~TFC3(),
    ~M_TDC(),
    ~LEN_M_TDC(),
    ~STMC1(),  # Rather slow due many similarity calculations.
    ~STMC1_f(),  # Rather slow due many similarity calculations.
    ~STMC2(),
    ~STMC2_f(),
]
axiom_names = [axiom.axiom.name for axiom in axioms]

# %%
from ir_axioms.backend.pyterrier.experiment import AxiomaticExperiment

experiment = AxiomaticExperiment(
    retrieval_systems=results,
    topics=dataset.get_topics(),
    qrels=dataset.get_qrels(),
    index=index_dir,
    dataset=ir_dataset,
    axioms=axioms,
    depth=depth,
    filter_by_qrels=False,
    filter_by_topics=False,
    verbose=True,
    cache_dir=cache_dir,
)

# %%
preferences = experiment.preferences
# Out:
# Computing system axiomatic preferences:   0%|          | 0/37 [00:00<?, ?system/s]
# Computing query axiom preferences:   0%|          | 0/43 [00:00<?, ?query/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <module>
# ----> 1 preferences = axiomatic_experiment.preferences
#       2 preferences
#
# File /usr/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/Development/webis/ir_axioms/ir_axioms/backend/pyterrier/experiment.py:117, in AxiomaticExperiment.preferences(self)
#     111 if self.verbose:
#     112     pipelines = tqdm(
#     113         pipelines,
#     114         desc="Computing system axiomatic preferences",
#     115         unit="system",
#     116     )
# --> 117 return concat([
#     118     pipeline.transform(self.topics)
#     119     for pipeline in pipelines
#     120 ])
#
# File ~/Development/webis/ir_axioms/ir_axioms/backend/pyterrier/experiment.py:118, in <listcomp>(.0)
#     111 if self.verbose:
#     112     pipelines = tqdm(
#     113         pipelines,
#     114         desc="Computing system axiomatic preferences",
#     115         unit="system",
#     116     )
#     117 return concat([
# --> 118     pipeline.transform(self.topics)
#     119     for pipeline in pipelines
#     120 ])
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/pyterrier/transformer.py:879, in ComposedPipeline.transform(self, topics)
#     877 def transform(self, topics):
#     878     for m in self.models:
# --> 879         topics = m.transform(topics)
#     880     return topics
#
# File ~/Development/webis/ir_axioms/ir_axioms/backend/pyterrier/transformers.py:59, in PerGroupTransformer.transform(self, topics_or_res)
#      53 if self.verbose:
#      54     # Show progress during reranking queries.
#      55     tqdm.pandas(
#      56         desc=self.description,
#      57         unit=self.unit,
#      58     )
# ---> 59     query_rankings = query_rankings.progress_apply(
#      60         self.transform_group
#      61     )
#      62 else:
#      63     query_rankings = query_rankings.apply(self.transform_group)
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1414, in GroupBy.apply(self, func, *args, **kwargs)
#    1412 with option_context("mode.chained_assignment", None):
#    1413     try:
# -> 1414         result = self._python_apply_general(f, self._selected_obj)
#    1415     except TypeError:
#    1416         # gh-20949
#    1417         # try again, with .apply acting as a filtering
#    (...)
#    1421         # fails on *some* columns, e.g. a numeric operation
#    1422         # on a string grouper column
#    1424         with self._group_selection_context():
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1455, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1429 @final
#    1430 def _python_apply_general(
#    1431     self,
#    (...)
#    1434     not_indexed_same: bool | None = None,
#    1435 ) -> DataFrame | Series:
#    1436     """
#    1437     Apply function f in python space
#    1438
#    (...)
#    1453         data after applying f
#    1454     """
# -> 1455     values, mutated = self.grouper.apply(f, data, self.axis)
#    1457     if not_indexed_same is None:
#    1458         not_indexed_same = mutated or self.mutated
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:761, in BaseGrouper.apply(self, f, data, axis)
#     759 # group might be modified
#     760 group_axes = group.axes
# --> 761 res = f(group)
#     762 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763     mutated = True
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# File ~/Development/webis/ir_axioms/ir_axioms/backend/pyterrier/transformers.py:134, in AxiomTransformer.transform_group(self, topics_or_res)
#     124 else:
#     125     documents = [
#     126         RankedDocument(
#     127             id=row["docno"],
#    (...)
#     131         for index, row in topics_or_res.iterrows()
#     132     ]
# --> 134 return self.transform_query_ranking(query, documents, topics_or_res)
#
# File ~/Development/webis/ir_axioms/ir_axioms/backend/pyterrier/transformers.py:313, in AxiomaticPreferences.transform_query_ranking(self, query, documents, topics_or_res)
#     306     if self.verbose and 0 < logger.level <= DEBUG:
#     307         # Very verbose progress bars.
#     308         document_pairs = tqdm(
#     309             document_pairs,
#     310             desc="Computing axiom preference",
#     311             unit="pair",
#     312         )
# --> 313     pairs[f"{name}_preference"] = [
#     314         axiom.preference(context, query, document1, document2)
#     315         for document1, document2 in document_pairs
#     316     ]
#     318 return pairs
#
# File ~/Development/webis/ir_axioms/ir_axioms/backend/pyterrier/transformers.py:314, in <listcomp>(.0)
#     306     if self.verbose and 0 < logger.level <= DEBUG:
#     307         # Very verbose progress bars.
#     308         document_pairs = tqdm(
#     309             document_pairs,
#     310             desc="Computing axiom preference",
#     311             unit="pair",
#     312         )
#     313     pairs[f"{name}_preference"] = [
# --> 314         axiom.preference(context, query, document1, document2)
#     315         for document1, document2 in document_pairs
#     316     ]
#     318 return pairs
#
# File ~/Development/webis/ir_axioms/ir_axioms/axiom/cache.py:60, in CachedAxiom.preference(self, context, query, document1, document2)
#      57     return preference
#      59 # Cache miss.
# ---> 60 preference = self.axiom.preference(
#      61     context,
#      62     query,
#      63     document1,
#      64     document2
#      65 )
#      66 cache[key] = preference
#      67 return preference
#
# File ~/Development/webis/ir_axioms/ir_axioms/axiom/preconditions.py:66, in LEN_Mixin.preference(self, context, query, document1, document2)
#      58 if not approximately_same_length(
#      59         context,
#      60         document1,
#    (...)
#      63 ):
#      64     # Documents have different lengths.
#      65     return 0
# ---> 66 return super().preference(context, query, document1, document2)
#
# File ~/Development/webis/ir_axioms/ir_axioms/axiom/argumentative.py:231, in QueryTermOccurrenceInArgumentativeUnitsAxiom.preference(self, context, query, document1, document2)
#     228 arguments1 = self.fetch_arguments(context, document1)
#     229 arguments2 = self.fetch_arguments(context, document2)
# --> 231 count1 = sum(
#     232     _count_query_terms(context, sentences, query)
#     233     for _, sentences in arguments1.items()
#     234 )
#     235 count2 = sum(
#     236     _count_query_terms(context, sentences, query)
#     237     for _, sentences in arguments2.items()
#     238 )
#     240 if count1 > count2:
#
# File ~/Development/webis/ir_axioms/ir_axioms/axiom/argumentative.py:232, in <genexpr>(.0)
#     228 arguments1 = self.fetch_arguments(context, document1)
#     229 arguments2 = self.fetch_arguments(context, document2)
#     231 count1 = sum(
# --> 232     _count_query_terms(context, sentences, query)
#     233     for _, sentences in arguments1.items()
#     234 )
#     235 count2 = sum(
#     236     _count_query_terms(context, sentences, query)
#     237     for _, sentences in arguments2.items()
#     238 )
#     240 if count1 > count2:
#
# File ~/Development/webis/ir_axioms/ir_axioms/axiom/argumentative.py:91, in _count_query_terms(context, sentences, query, normalize)
#      89 term_count = 0
#      90 for term in context.terms(query):
# ---> 91     normalized_term = _normalize(term) if normalize else term
#      92     for sentence in sentences:
#      93         for tag in sentence:
#
# File ~/Development/webis/ir_axioms/ir_axioms/axiom/argumentative.py:22, in _normalize(word)
#      20 download_nltk_dependencies("wordnet", "omw-1.4")
#      21 _word_net_lemmatizer = WordNetLemmatizer()
# ---> 22 return _word_net_lemmatizer.lemmatize(word).lower()
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/stem/wordnet.py:45, in WordNetLemmatizer.lemmatize(self, word, pos)
#      33 def lemmatize(self, word: str, pos: str = "n") -> str:
#      34     """Lemmatize `word` using WordNet's built-in morphy function.
#      35     Returns the input word unchanged if it cannot be found in WordNet.
#      36
#    (...)
#      43     :return: The lemma of `word`, for the given `pos`.
#      44     """
# ---> 45     lemmas = wn._morphy(word, pos)
#      46     return min(lemmas, key=len) if lemmas else word
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/corpus/util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/corpus/util.py:89, in LazyCorpusLoader.__load(self)
#      86             raise e
#      88 # Load the corpus.
# ---> 89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#      91 # This is where the magic happens!  Transform ourselves into
#      92 # the corpus by modifying our own __dict__ and __class__ to
#      93 # match that of the corpus.
#      95 args, kwargs = self.__args, self.__kwargs
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:1195, in WordNetCorpusReader.__init__(self, root, omw_reader)
#    1192         self._lexnames.append(lexname)
#    1194 # Load the indices for lemmas and synset offsets
# -> 1195 self._load_lemma_pos_offset_map()
#    1197 # load the exception file data into memory
#    1198 self._load_exception_map()
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:1307, in WordNetCorpusReader._load_lemma_pos_offset_map(self)
#    1303 for suffix in self._FILEMAP.values():
#    1304
#    1305     # parse each line of the file (ignoring comment lines)
#    1306     with self.open("index.%s" % suffix) as fp:
# -> 1307         for i, line in enumerate(fp):
#    1308             if line.startswith(" "):
#    1309                 continue
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/data.py:1152, in SeekableUnicodeStreamReader.__next__(self)
#    1151 def __next__(self):
# -> 1152     return self.next()
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/data.py:1145, in SeekableUnicodeStreamReader.next(self)
#    1143 def next(self):
#    1144     """Return the next decoded line from the underlying stream."""
# -> 1145     line = self.readline()
#    1146     if line:
#    1147         return line
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/data.py:1100, in SeekableUnicodeStreamReader.readline(self, size)
#    1098 while True:
#    1099     startpos = self.stream.tell() - len(self.bytebuffer)
# -> 1100     new_chars = self._read(readsize)
#    1102     # If we're at a '\r', then read one extra character, since
#    1103     # it might be a '\n', to get the proper line ending.
#    1104     if new_chars and new_chars.endswith("\r"):
#
# File ~/Development/webis/ir_axioms/venv/lib/python3.9/site-packages/nltk/data.py:1344, in SeekableUnicodeStreamReader._read(self, size)
#    1341 bytes = self.bytebuffer + new_bytes
#    1343 # Decode the bytes into unicode characters
# -> 1344 chars, bytes_decoded = self._incr_decode(bytes)
#    1346 # If we got bytes but couldn't decode any, then read further.
#    1347 if (size is not None) and (not chars) and (len(new_bytes) > 0):
#
# KeyboardInterrupt:

# %%
preferences.to_csv(f"trec-{edition}-{track}-preferences-all-axioms-depth-{depth}.csv")
