# %% [markdown]
# # `ir_axioms`: Evaluation on TREC DL 19/20 MSMARCO (Passage)

# %%
import ir_datasets
import pyterrier as pt
if not pt.started():
    pt.init(tqdm="notebook")

from ir_axioms.backend.pyterrier.experiment import AxiomaticExperiment
from ir_axioms.axiom import TFC1, LNC1
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_1017623/2010683653.py in <module>
#       2 import pyterrier as pt
#       3 if not pt.started():
# ----> 4     pt.init(tqdm="notebook")
#       5
#       6 from ir_axioms.backend.pyterrier.experiment import AxiomaticExperiment
#
# /opt/conda/lib/python3.8/site-packages/pyterrier/__init__.py in init(version, mem, packages, jvm_opts, redirect_io, logging, home_dir, boot_packages, tqdm, no_download, helper_version)
#     120     if mem is not None:
#     121         jnius_config.add_options('-Xmx' + str(mem) + 'm')
# --> 122     from jnius import autoclass, cast
#     123
#     124     # we only accept Java version 11 and newer; so anything starting 1. or 9. is too old
#
# /opt/conda/lib/python3.8/site-packages/jnius/__init__.py in <module>
#      40 else:
#      41     from .jnius import *  # noqa
# ...

# %%
def from_ird_qrels(ird_name):
    import ir_datsets
    import pandas as pd
    import pyterrier as pt
    
    qrels = ir_datasets.load(ird_name).qrels.asdict()
    ret = []
    for qid, judgments in qrels.items():
    
    return pt.from_df(pd.DataFrame([qid 	docno 	rank 	score 	name]))

# %%
ir_datasets.load('msmarco-passage/trec-dl-2019/judged').qrels.asdict()
# Out:
# {'19335': {'1017759': 0,
#   '1082489': 0,
#   '109063': 0,
#   '1160863': 0,
#   '1160871': 0,
#   '1189088': 0,
#   '1203500': 0,
#   '1231806': 0,
#   '1231807': 0,
#   '1274615': 0,
#   '1274620': 0,
#   '1324075': 0,
#   '1509459': 0,
#   '1555317': 0,
#   '1568085': 0,
#   '161603': 0,
#   '1705525': 0,
#   '1720387': 0,
#   '1720388': 0,
#   '1720389': 1,
#   '1720393': 0,
#   '1720395': 1,
#   '1722': 0,
#   '1725697': 0,
#   '1726': 0,
#   '1729': 2,
#   '1730': 0,
#   '1796642': 0,
#   '1796647': 0,
#   '1825416': 0,
#   '1825418': 0,
#   '1837110': 0,
#   '1871222': 0,
#   '1908804': 0,
#   '1956669': 0,
#   '1958100': 0,
#   '1958102': 0,
#   '1958103': 0,
#   '1959553': 0,
#   '2004186': 0,
#   '2046505': 1,
#   '2071723': 0,
#   '2130187': 0,
#   '2186129': 0,
#   '2304004': 0,
#   '2304005': 0,
#   '2324839': 0,
#   '2325143': 0,
#   '2382766': 0,
#   '2394677': 0,
#   '256744': 0,
#   '256746': 0,
#   '256750': 0,
#   '2594897': 0,
#   '2604487': 0,
#   '2725017': 0,
# ...

# %%
ir_datasets.load.__doc__

# %%
# !pip in
